# %% [markdown]
# ## Deapth First Search

# %%
from graph_utils import *

# %%
Image("images/directed_graph.jpeg",width=600,height=400)

# %%
edges=[('a','b'),('a','c'),('a','d'),
('b','e'),
('c','d'),('c','e'),
('d','f'),
('e','a'),
('f','g'),('f','e'),
('g','c'),]

# %% [markdown]
# ### Possible paths between two nodes

# %%
g=create_graph(edges,directed=False)

# %%
def DFS(graph,node,path):
    if vertex.state!=-1
        vertex=graph.nodes[node]
        vertex.state=-1
        connections=vertex.connectedTo.keys()
        if len(connections):
            for v in connections:
                if vertex.state!=-1
                    DFS(graph,v)
    else:return []
